# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/138.0.0.0 Safari/537.36'
}

webpage = requests.get(
    'https://www.ambitionbox.com/list-of-companies?page=1',
    headers=headers
).text

# %%
Soup = BeautifulSoup(webpage , 'lxml')

# %%
Company = Soup.find_all('div' , class_='companyCardWrapper__primaryInformation')

# %%
len(Company)
# Out:
# 20

# %%
Name = []
Rating = []
Reviews = []
Ctype = []
Hq = []
HR = []
CR = []
for i in Company:
    Name.append(i.find('h2').text.strip())
    Rating.append(i.find('div',class_='rating_text rating_text--md').text.strip())
    Reviews.append(i.find('span',class_='companyCardWrapper__companyRatingCount').text.strip())
    info = i.find('span', class_='companyCardWrapper__interLinking').text.strip().split('|')
    Ctype.append(info[0].strip())
    Hq.append(info[1].strip())
    ratings = i.find_all('span', class_='companyCardWrapper__ratingValues')
    HR.append(ratings[0].text.strip() if len(ratings) > 0 else None)
    CR.append(ratings[1].text.strip() if len(ratings) > 1 else None)

D = {'Name':Name,'Rating':Rating,'Reviews':Reviews,'Company_Type':Ctype,'Headquaters':Hq,'Highly Rated':HR,'Critically Rated':CR}
df = pd.DataFrame(D)
df
# Out:
#                       Name Rating  Reviews              Company_Type  \
# 0                      TCS    3.3   (1.2L)  IT Services & Consulting
# 1                Accenture    3.7  (75.2k)  IT Services & Consulting
# 2                    Wipro    3.6  (66.4k)  IT Services & Consulting
# 3                Cognizant    3.7  (62.7k)  IT Services & Consulting
# 4                Capgemini    3.6  (54.8k)  IT Services & Consulting
# 5                HDFC Bank    3.8  (53.9k)                   Banking
# 6                  Infosys    3.5  (49.9k)  IT Services & Consulting
# 7                  HCLTech    3.4    (47k)  IT Services & Consulting
# 8               ICICI Bank    4.0  (46.7k)                   Banking
# 9            Tech Mahindra    3.3  (44.2k)  IT Services & Consulting
# 10                 Genpact    3.6  (43.4k)           Analytics & KPO
# 11                      TP    3.9  (39.7k)                       BPO
# 12               Axis Bank    3.6  (34.1k)                   Banking
# 13                     Jio    4.4  (34.1k)                   Telecom
# 14  Concentrix Corporation    3.5  (32.9k)                       BPO
# 15                  Amazon    3.9  (32.4k)                  Internet
# 16         Reliance Retail    3.9  (27.8k)                    Retail
# 17              iEnergizer    4.6  (27.5k)                       BPO
# 18             LTM Limited    3.6    (27k)  IT Services & Consulting
# 19  HDB Financial Services    3.9  (26.3k)                      NBFC
#
#                        Headquaters  \
# 0   Bengaluru +448 other locations
# 1   Bengaluru +261 other locations
# 2   Hyderabad +375 other locations
# 3   Hyderabad +233 other locations
# 4   Bengaluru +188 other locations
# 5     Mumbai +1865 other locations
# 6   Bengaluru +247 other locations
# 7     Chennai +232 other locations
# 8     Mumbai +1449 other locations
# 9   Hyderabad +323 other locations
# 10  Hyderabad +181 other locations
# 11     Mumbai +259 other locations
# 12    Mumbai +1535 other locations
# 13    Mumbai +1966 other locations
# 14  Bengaluru +185 other locations
# 15  Bengaluru +521 other locations
# 16    Mumbai +1167 other locations
# 17       Noida +55 other locations
# 18  Bengaluru +146 other locations
# 19    Mumbai +1099 other locations
#
#                                          Highly Rated  \
# 0                                        Job Security
# 1               Promotions, Salary, Work Satisfaction
# 2               Promotions, Salary, Work Satisfaction
# 3               Promotions, Salary, Work Satisfaction
# 4                     Work Life Balance, Job Security
# 5                     Job Security, Skill Development
# 6                                        Job Security
# 7               Promotions, Salary, Work Satisfaction
# 8         Job Security, Promotions, Skill Development
# 9               Promotions, Salary, Work Satisfaction
# 10                                       Job Security
# 11  Work Life Balance, Job Security, Skill Develop...
# 12     Promotions, Work Satisfaction, Company Culture
# 13   Job Security, Skill Development, Company Culture
# 14                                       Job Security
# 15         Company Culture, Work Life Balance, Salary
# 16  Job Security, Skill Development, Work Life Bal...
# 17  Company Culture, Work Life Balance, Work Satis...
# 18              Promotions, Salary, Work Satisfaction
# 19                                 Promotions, Salary
#
#                          Critically Rated
# 0   Promotions, Salary, Work Satisfaction
# 1                                    None
# 2                                    None
# 3                                    None
# 4   Promotions, Salary, Work Satisfaction
# 5                      Promotions, Salary
# 6   Promotions, Salary, Work Satisfaction
# 7                                    None
# 8                                    None
# 9                                    None
# 10  Promotions, Salary, Work Satisfaction
# 11                                   None
# 12                                   None
# 13                                   None
# 14  Promotions, Salary, Work Satisfaction
# 15                             Promotions
# 16                             Promotions
# 17                                   None
# 18                                   None
# 19                                   None

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

Final = pd.DataFrame()

headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/138.0.0.0 Safari/537.36'
}

for j in range(1, 11):

    url = f'https://www.ambitionbox.com/list-of-companies?page={j}'

    webpage = requests.get(url, headers=headers).text

    Soup = BeautifulSoup(webpage, 'lxml')

    Company = Soup.find_all('div', class_='companyCardWrapper__primaryInformation')

    Name = []
    Rating = []
    Reviews = []
    Ctype = []
    Hq = []
    HR = []
    CR = []

    for i in Company:

        Name.append(i.find('h2').text.strip())

        Rating.append(i.find('div', class_='rating_text rating_text--md').text.strip())

        Reviews.append(i.find('span', class_='companyCardWrapper__companyRatingCount').text.strip())

        info = i.find('span', class_='companyCardWrapper__interLinking').text.strip().split('|')

        Ctype.append(info[0].strip())

        Hq.append(info[1].strip() if len(info) > 1 else None)

        ratings = i.find_all('span', class_='companyCardWrapper__ratingValues')

        HR.append(ratings[0].text.strip() if len(ratings) > 0 else None)

        CR.append(ratings[1].text.strip() if len(ratings) > 1 else None)

    df = pd.DataFrame({
        'Name': Name,
        'Rating': Rating,
        'Reviews': Reviews,
        'Company Type': Ctype,
        'Headquarters': Hq,
        'Highly Rated For': HR,
        'Critically Rated For': CR
    })

    Final = pd.concat([Final, df], ignore_index=True)

print(Final.shape)
Final.head(50)
# Out:
# (200, 7)
#                        Name Rating  Reviews                Company Type  \
# 0                       TCS    3.3   (1.2L)    IT Services & Consulting
# 1                 Accenture    3.7  (75.2k)    IT Services & Consulting
# 2                     Wipro    3.6  (66.4k)    IT Services & Consulting
# 3                 Cognizant    3.7  (62.7k)    IT Services & Consulting
# 4                 Capgemini    3.6  (54.8k)    IT Services & Consulting
# 5                 HDFC Bank    3.8  (53.9k)                     Banking
# 6                   Infosys    3.5  (49.9k)    IT Services & Consulting
# 7                   HCLTech    3.4    (47k)    IT Services & Consulting
# 8                ICICI Bank    4.0  (46.7k)                     Banking
# 9             Tech Mahindra    3.3  (44.2k)    IT Services & Consulting
# 10                  Genpact    3.6  (43.4k)             Analytics & KPO
# 11                       TP    3.9  (39.7k)                         BPO
# 12                Axis Bank    3.6  (34.1k)                     Banking
# 13                      Jio    4.4  (34.1k)                     Telecom
# 14   Concentrix Corporation    3.5  (32.9k)                         BPO
# 15                   Amazon    3.9  (32.4k)                    Internet
# 16          Reliance Retail    3.9  (27.8k)                      Retail
# 17               iEnergizer    4.6  (27.5k)                         BPO
# 18              LTM Limited    3.6    (27k)    IT Services & Consulting
# 19   HDB Financial Services    3.9  (26.3k)                        NBFC
# 20                      IBM    3.9  (26.2k)    IT Services & Consulting
# 21  Larsen & Toubro Limited    3.9  (24.4k)  Engineering & Construction
# 22                 Deloitte    3.6  (23.9k)       Management Consulting
# 23      Kotak Mahindra Bank    3.6    (23k)                     Banking
# 24      Reliance Industries    4.0  (20.6k)                   Oil & Gas
# 25            Vodafone Idea    3.9  (17.8k)                     Telecom
# 26            Bharti Airtel    3.8  (17.4k)                     Telecom
# 27                   BYJU'S    3.2  (16.4k)                      EdTech
# 28                      WNS    3.3  (15.6k)    IT Services & Consulting
# 29          IDFC FIRST Bank    4.0  (15.3k)                     Banking
# 30            Ernst & Young    3.4    (15k)       Management Consulting
# 31            IndusInd Bank    3.4  (14.6k)                     Banking
# 32    AU Small Finance Bank    3.8  (14.5k)                     Banking
# 33              Tata Motors    4.1  (14.4k)                  Automobile
# 34            Bajaj Finserv    3.9  (13.6k)                        NBFC
# 35          Muthoot FinCorp    4.5  (13.3k)                        NBFC
# 36                 Flipkart    3.9  (13.3k)                    Internet
# 37                      PwC    3.3  (13.1k)       Management Consulting
# 38                HDFC Life    3.8  (12.4k)                   Insurance
# 39      Mahindra & Mahindra    4.0  (12.3k)                  Automobile
# 40              Infosys BPM    3.5  (12.3k)                         BPO
# 41           DXC Technology    3.6  (12.2k)    IT Services & Consulting
# 42             Bandhan Bank    3.7  (11.6k)                     Banking
# 43       Digitide Solutions    3.4  (10.6k)    IT Services & Consulting
# 44                 Yes Bank    3.7  (10.5k)                     Banking
# 45                  Mphasis    3.3  (10.5k)    IT Services & Consulting
# 46               Tata Steel    4.0  (10.1k)                Iron & Steel
# 47                    Quess    3.8    (10k)                 Recruitment
# 48             Asian Paints    3.9   (9.9k)                   Chemicals
# 49         UltraTech Cement    4.1   (9.8k)           Building Material
#
#                        Headquarters  \
# 0    Bengaluru +448 other locations
# 1    Bengaluru +261 other locations
# 2    Hyderabad +375 other locations
# 3    Hyderabad +233 other locations
# 4    Bengaluru +188 other locations
# 5      Mumbai +1865 other locations
# 6    Bengaluru +247 other locations
# 7      Chennai +232 other locations
# 8      Mumbai +1449 other locations
# 9    Hyderabad +323 other locations
# 10   Hyderabad +181 other locations
# 11      Mumbai +259 other locations
# 12     Mumbai +1535 other locations
# 13     Mumbai +1966 other locations
# 14   Bengaluru +185 other locations
# 15   Bengaluru +521 other locations
# 16     Mumbai +1167 other locations
# 17        Noida +55 other locations
# 18   Bengaluru +146 other locations
# 19     Mumbai +1099 other locations
# 20   Bengaluru +162 other locations
# 21      Mumbai +781 other locations
# 22   Hyderabad +186 other locations
# 23      Mumbai +697 other locations
# 24    Jamnagar +822 other locations
# 25        Pune +708 other locations
# 26    Gurugram +797 other locations
# 27   Bengaluru +321 other locations
# 28         Pune +69 other locations
# 29      Mumbai +746 other locations
# 30   Bengaluru +135 other locations
# 31      Mumbai +805 other locations
# 32      Jaipur +810 other locations
# 33        Pune +510 other locations
# 34       Pune +1220 other locations
# 35  Bengaluru +1126 other locations
# 36   Bengaluru +560 other locations
# 37   Bengaluru +139 other locations
# 38      Mumbai +724 other locations
# 39        Pune +570 other locations
# 40    Bengaluru +95 other locations
# 41   Bengaluru +132 other locations
# 42    Kolkata +1027 other locations
# 43   Hyderabad +276 other locations
# 44      Mumbai +545 other locations
